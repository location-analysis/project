# %%
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.1.0)
# Requirement already satisfied: phik>=0.11.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (0.12.0)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (0.7.4)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (0.1.0)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (4.63.0)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (3.5.1)
# Requirement already satisfied: multimethod>=1.4 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (1.7)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (1.4.1)
# Requirement already satisfied: joblib~=1.0.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (1.0.1)
# Requirement already satisfied: markupsafe~=2.0.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (2.0.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (1.8.0)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (1.9.0)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (3.0.3)
# Requirement already satisfied: requests>=2.24.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (2.27.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (1.22.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas-profiling) (0.5.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (2.7.1)
# Requirement already satisfied: imagehash in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.2.1)
# Requirement already satisfied: Pillow in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.24.0->pandas-profiling) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.24.0->pandas-profiling) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.11)
# Requirement already satisfied: colorama in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.2.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: C:\Users\dkq50\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# 버전 확인
! pip show pandas_profiling
# Out:
# Name: pandas-profiling
# Version: 3.1.0
# Summary: Generate profile report for pandas DataFrame
# Home-page: https://github.com/pandas-profiling/pandas-profiling
# Author: Simon Brugman
# Author-email: pandasprofiling@gmail.com
# License: MIT
# Location: c:\users\dkq50\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages
# Requires: htmlmin, jinja2, joblib, markupsafe, matplotlib, missingno, multimethod, numpy, pandas, phik, pydantic, PyYAML, requests, scipy, seaborn, tangled-up-in-unicode, tqdm, visions
# Required-by:

# %%
## 파일불러오기
import pandas as pd
import pandas_profiling

gagu_1 = pd.read_csv('data/2021_1인가구비율.csv', encoding='cp949')
ap = pd.read_csv('data/202112_202112_연령별인구현황_연간.csv', encoding='cp949')
bus = pd.read_csv('data/대구광역시_시내버스 정류소 위치정보_20220731.csv', encoding='cp949')
parking = pd.read_csv('data/대구광역시_주차장정보_20220602.csv', encoding='cp949')
subway = pd.read_csv('data/대구도시철도공사_역별무료자전거운영현황_20220830.csv', encoding='cp949')
school = pd.read_csv('data/대구시 자치구별 대학교 학령인구 통계.csv', encoding='cp949')
dong = pd.read_csv('data/대구시 행정구역(동별).csv', encoding='cp949')
#ingumildo = pd.read_csv('data/인구밀도_인구주택총조사기준__20221010115042.csv', encoding='cp949')

# %% [markdown]
# 한글깨짐이 고쳐지지않는다는 단점..

# %%
############ 한글 폰트 지정하는 부분 #################
import matplotlib
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False   
#그래프에서 마이너스 기호가 표시되도록 하는 설정입니다.


# 레포트 생성 --> html 파일로 저장하기  
## 한글이 깨지시는 분은 제일 아래 코드로 실행해주세요
report = gagu_1.profile_report()
report.to_file('gagu_1.html')
# Out:
# Summarize dataset:  42%|████▏     | 10/24 [00:00<00:00, 98.41it/s, scatter 1인가구비율, 1인가구비율]       c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  46%|████▌     | 11/24 [00:00<00:00, 98.41it/s, scatter 1인가구, 1인가구비율]    c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  50%|█████     | 12/24 [00:00<00:00, 98.41it/s, scatter 일반가구, 1인가구비율]c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  54%|█████▍    | 13/24 [00:00<00:00, 98.41it/s, scatter 1인가구비율, 1인가구] c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  58%|█████▊    | 14/24 [00:00<00:00, 98.41it/s, scatter 1인가구, 1인가구]    c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  62%|██████▎   | 15/24 [00:00<00:00, 98.41it/s, scatter 일반가구, 1인가구]c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  67%|██████▋   | 16/24 [00:00<00:00, 98.41it/s, scatter 1인가구비율, 일반가구]c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  71%|███████   | 17/24 [00:00<00:00, 98.41it/s, scatter 1인가구, 일반가구]    c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  75%|███████▌  | 18/24 [00:00<00:00, 98.41it/s, scatter 일반가구, 일반가구]c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  77%|███████▋  | 20/26 [00:01<00:00, 16.29it/s, Missing diagram bar]       c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset:  81%|████████  | 21/26 [00:01<00:00, 16.29it/s, Missing diagram matrix]c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Summarize dataset: 100%|██████████| 26/26 [00:01<00:00, 19.39it/s, Completed]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 320.40it/s]

# %% [markdown]
# pandas_profiling 오류 시 사용

# %%
import pandas as pd
import sweetviz as sv

# %%
advert_report = sv.analyze(parking)
#display the report
advert_report.show_html('./대구광역시_주차장정보.html')
# Out:
# Feature: 주차장구분                               |▉         | [  9%]   00:00 -> (00:00 left)   c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 주차장유형                               |█▎        | [ 12%]   00:00 -> (00:00 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45432 (\N{HANGUL SYLLABLE NO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 급지구분                                |██▌       | [ 25%]   00:00 -> (00:02 left)  c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 부제시행구분                              |██▊       | [ 28%]   00:00 -> (00:02 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 운영요일                                |███▏      | [ 31%]   00:00 -> (00:01 left)  c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 평일운영시작시각                            |███▍      | [ 34%]   00:00 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 평일운영종료시각                            |███▊      | [ 38%]   00:01 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 토요일운영시작시각                           |████      | [ 41%]   00:01 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 토요일운영종료시각                           |████▍     | [ 44%]   00:01 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 공휴일운영시작시각                           |████▋     | [ 47%]   00:01 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 공휴일운영종료시각                           |█████     | [ 50%]   00:01 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 요금정보                                |█████▎    | [ 53%]   00:01 -> (00:01 left)     c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 주차기본요금                              |█████▉    | [ 59%]   00:01 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 추가단위요금                              |██████▌   | [ 66%]   00:02 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 1일주차권요금적용시간                         |██████▉   | [ 69%]   00:02 -> (00:01 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\series_analyzer.py:16: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts_without_nan = pd.Series()
# Feature: 1일주차권요금                             |███████▏  | [ 72%]   00:02 -> (00:00 left)    c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 월정기권요금                              |███████▌  | [ 75%]   00:02 -> (00:00 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# Feature: 결제방법                                |███████▊  | [ 78%]   00:02 -> (00:00 left)  c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 특기사항                                |████████▏ | [ 81%]   00:02 -> (00:00 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47924 (\N{HANGUL SYLLABLE MU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 관리기관명                               |████████▍ | [ 84%]   00:02 -> (00:00 left)c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Feature: 전화번호                                |████████▊ | [ 88%]   00:02 -> (00:00 left) c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# [Step 3/3] Generating associations graph     |          | [  0%]   00:00 -> (? left)       c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54925 (\N{HANGUL SYLLABLE HOEG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44553 (\N{HANGUL SYLLABLE GEUB}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54665 (\N{HANGUL SYLLABLE HAENG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51089 (\N{HANGUL SYLLABLE JAG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44033 (\N{HANGUL SYLLABLE GAG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47308 (\N{HANGUL SYLLABLE RYO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 55092 (\N{HANGUL SYLLABLE HYU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48376 (\N{HANGUL SYLLABLE BON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 52628 (\N{HANGUL SYLLABLE CU}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45800 (\N{HANGUL SYLLABLE DAN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44428 (\N{HANGUL SYLLABLE GWEON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48169 (\N{HANGUL SYLLABLE BANG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48277 (\N{HANGUL SYLLABLE BEOB}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 53945 (\N{HANGUL SYLLABLE TEUG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54637 (\N{HANGUL SYLLABLE HANG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 48264 (\N{HANGUL SYLLABLE BEON}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 54840 (\N{HANGUL SYLLABLE HO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# c:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\sweetviz\graph.py:33: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   figure.savefig(as_raw_bytes, format='png', transparent=True)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report ./대구광역시_주차장정보.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
